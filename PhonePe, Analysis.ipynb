# %% [markdown]
# # PhonePe- Analysis

# %% [raw]
# Dataframes
#
# State_txn= "State_Txn and Users"
# State_txnsplit= "State_TxnSplit"
# State_devicedata= "State_DeviceData"
# District_txn= "District_Txn and Users"
# District_demo= "District Demographics"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# 1.1 Question-1

State_txn= pd.read_excel("Phonepe_raw_data.xlsx", sheet_name= "State_Txn and Users")

State_txn.head(5)
# Out:
#                        State  Year  Quarter  Transactions  Amount (INR)  \
# 0  Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1  Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2  Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3  Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4  Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
#
#      ATV (INR)  Registered Users  App Opens
# 0  2197.621091              6740          0
# 1  2498.989022              9405          0
# 2  3415.768284             12149          0
# 3  3811.277720             15222          0
# 4  3355.630147             18596          0

# %%
#1.1 Question-2 Load the bottom 10 rows.
State_txnsplit= pd.read_excel("Phonepe_raw_data.xlsx", sheet_name = "State_TxnSplit")

State_txnsplit.tail(10)
# Out:
#             State  Year  Quarter          Transaction Type  Transactions  \
# 2504  West Bengal  2021        1     Peer-to-peer payments      53869075
# 2505  West Bengal  2021        1         Merchant payments      37143701
# 2506  West Bengal  2021        1  Recharge & bill payments      26673733
# 2507  West Bengal  2021        1        Financial Services        166727
# 2508  West Bengal  2021        1                    Others        400816
# 2509  West Bengal  2021        2     Peer-to-peer payments      64661051
# 2510  West Bengal  2021        2         Merchant payments      41696787
# 2511  West Bengal  2021        2  Recharge & bill payments      34799709
# 2512  West Bengal  2021        2        Financial Services        190537
# 2513  West Bengal  2021        2                    Others        549353
#
#       Amount (INR)    ATV (INR)
# 2504  2.022402e+11  3754.292226
# 2505  2.891834e+10   778.553104
# 2506  1.133967e+10   425.124820
# 2507  1.754458e+08  1052.293941
# 2508  2.635025e+08   657.415236
# 2509  2.308123e+11  3569.572026
# 2510  3.478787e+10   834.305703
# 2511  1.333145e+10   383.090958
# 2512  1.864665e+08   978.636630
# 2513  3.167447e+08   576.577748

# %%
#1.1 Question-3 Display the middle 10 rows from the dataset.

State_devicedata = pd.read_excel("Phonepe_raw_data.xlsx", sheet_name = "State_DeviceData")

start = len(State_devicedata)/2 - 5
end = len(State_devicedata)/2 + 5

State_devicedata.loc[start:end]
# Out:
#             State  Year  Quarter     Brand  Registered Users  Percentage
# 2767       Ladakh  2021        2   OnePlus              1741    0.023198
# 2768       Ladakh  2021        2  Motorola               922    0.012285
# 2769       Ladakh  2021        2    Huawei               894    0.011912
# 2770       Ladakh  2021        2    Lenovo               490    0.006529
# 2771       Ladakh  2021        2    Others              2610    0.034778
# 2772  Lakshadweep  2018        1   Samsung               102    0.203593
# 2773  Lakshadweep  2018        1    Xiaomi               100    0.199601
# 2774  Lakshadweep  2018        1      Vivo                67    0.133733
# 2775  Lakshadweep  2018        1      Oppo                56    0.111776
# 2776  Lakshadweep  2018        1    Huawei                25    0.049900
# 2777  Lakshadweep  2018        1   OnePlus                22    0.043912

# %%
#1.1 Question-4 First 10 and last 10

District_txn= pd.read_excel("Phonepe_raw_data.xlsx", sheet_name = "District_Txn and Users")

District_txn.head(10)
District_txn.tail(10)
# Out:
#              State  Year  Quarter                    District  Code  \
# 10238  West Bengal  2021        2                 Murshidabad  WB14
# 10239  West Bengal  2021        2                       Nadia  WB15
# 10240  West Bengal  2021        2  North Twenty Four Parganas  WB16
# 10241  West Bengal  2021        2           Paschim Bardhaman  WB17
# 10242  West Bengal  2021        2           Paschim Medinipur  WB18
# 10243  West Bengal  2021        2             Purba Bardhaman  WB19
# 10244  West Bengal  2021        2             Purba Medinipur  WB20
# 10245  West Bengal  2021        2                     Purulia  WB21
# 10246  West Bengal  2021        2  South Twenty Four Parganas  WB22
# 10247  West Bengal  2021        2              Uttar Dinajpur  WB23
#
#        Transactions  Amount (INR)    ATV (INR)  Registered Users  App Opens
# 10238       8602251  1.999694e+10  2324.616616           1248602   16530655
# 10239       5524174  1.122758e+10  2032.445525            955428   13665885
# 10240      17258291  3.041482e+10  1762.331031           2660664   37899453
# 10241       4893774  8.731263e+09  1784.157359            789026   10545670
# 10242       5051834  1.030351e+10  2039.558976            856640   16201033
# 10243       3920729  7.572502e+09  1931.401639            787970   12128849
# 10244       6418522  1.515507e+10  2361.146027            946277   15491958
# 10245       1895981  2.790996e+09  1472.059252            435131    8843358
# 10246       6661813  1.339853e+10  2011.243709           1286588   19344293
# 10247       2253385  5.564221e+09  2469.272118            392388    8184990

# %%
#1.1 Question-5 Display every 10th Row.
District_demo= pd.read_excel("Phonepe_raw_data.xlsx", sheet_name= "District Demographics")

District_demo[0:len(District_demo)+1:10]
# Out:
#                  State       District   Headquarters  Population  \
# 0       Andhra Pradesh      Anantapur      Anantapur     4083315
# 10      Andhra Pradesh  Visakhapatnam  Visakhapatnam     4288113
# 20   Arunachal Pradesh      Lepa Rada          Basar           0
# 30   Arunachal Pradesh          Siang         Pangin       31920
# 40               Assam        Barpeta        Barpeta     1693622
# ..                 ...            ...            ...         ...
# 700         Chandigarh     Chandigarh     Chandigarh     1055450
# 710    Jammu & Kashmir          Jammu          Jammu     1526406
# 720    Jammu & Kashmir          Samba          Samba      318611
# 730              Delhi    North Delhi   Sadar Bazaar      887978
# 740         Puducherry     Puducherry    Pondicherry      950289
#
#      Area (sq km)  Density  Code Alternate Name
# 0         19130.0      213  AP01      Anantapur
# 10        11161.0      384  AP10  Visakhapatnam
# 20            0.0        0  AR08      Lepa Rada
# 30         2919.0       11  AR18          Siang
# 40         3245.0      520  AS03        Barpeta
# ..            ...      ...   ...            ...
# 700         114.0     9258  CH01     Chandigarh
# 710        3097.0      596  JK07          Jammu
# 720         913.0      318  JK17          Samba
# 730          59.0    14557  DL04          North
# 740         293.0     3232  PY03     Puducherry
#
# [75 rows x 8 columns]

# %%
#1.2 Question-1 Summary.

State_txn.describe()
State_txnsplit.describe()
State_devicedata.describe()
District_txn.describe()
District_demo.describe()
# Out:
#          Population  Area (sq km)       Density
# count  7.420000e+02    742.000000    742.000000
# mean   1.668555e+06   4395.373120    838.512129
# std    1.458849e+06   4254.676124   2754.406896
# min    0.000000e+00      0.000000      0.000000
# 25%    6.530815e+05   2039.750000    198.000000
# 50%    1.322359e+06   3402.500000    353.000000
# 75%    2.297440e+06   5432.750000    686.250000
# max    1.008285e+07  45652.000000  36155.000000

# %%
#1.2 Question-2 Datatype.

State_txn.info()
State_txnsplit.info()
State_devicedata.info()
District_txn.info()
District_demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             504 non-null    object
#  1   Year              504 non-null    int64
#  2   Quarter           504 non-null    int64
#  3   Transactions      504 non-null    int64
#  4   Amount (INR)      503 non-null    float64
#  5   ATV (INR)         504 non-null    float64
#  6   Registered Users  504 non-null    int64
#  7   App Opens         504 non-null    int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 31.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2514 entries, 0 to 2513
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             2514 non-null   object
#  1   Year              2514 non-null   int64
#  2   Quarter           2514 non-null   int64
#  3   Transaction Type  2514 non-null   object
#  4   Transactions      2514 non-null   int64
#  5   Amount (INR)      2514 non-null   float64
#  6   ATV (INR)         2514 non-null   float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 137.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5544 entries, 0 to 5543
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             5544 non-null   object
#  1   Year              5544 non-null   int64
#  2   Quarter           5544 non-null   int64
#  3   Brand             5544 non-null   object
#  4   Registered Users  5544 non-null   int64
#  5   Percentage        5544 non-null   float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 260.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10248 entries, 0 to 10247
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             10248 non-null  object
#  1   Year              10248 non-null  int64
#  2   Quarter           10248 non-null  int64
#  3   District          10248 non-null  object
#  4   Code              10220 non-null  object
#  5   Transactions      10248 non-null  int64
#  6   Amount (INR)      10248 non-null  float64
#  7   ATV (INR)         10244 non-null  float64
#  8   Registered Users  10248 non-null  int64
#  9   App Opens         10248 non-null  int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 800.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   State           742 non-null    object
#  1   District        742 non-null    object
#  2   Headquarters    742 non-null    object
#  3   Population      742 non-null    int64
#  4   Area (sq km)    742 non-null    float64
#  5   Density         742 non-null    int64
#  6   Code            742 non-null    object
#  7   Alternate Name  742 non-null    object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 46.5+ KB

# %%
#1.3 Question-1 Missing values.

State_txn.isnull().sum()
State_txnsplit.isnull().sum()
State_devicedata.isnull().sum()
District_txn.isnull().sum()
District_demo.isnull().sum()
# Out:
# State             0
# District          0
# Headquarters      0
# Population        0
# Area (sq km)      0
# Density           0
# Code              0
# Alternate Name    0
# dtype: int64

# %%
#1.3 Question-2 Percentage of missing values in a column.

## Missing values.
State_txn.isnull().mean()*100
State_txnsplit.isnull().mean()*100
State_devicedata.isnull().mean()*100
District_txn.isnull().mean()*100
District_demo.isnull().mean()*100
# Out:
# State             0.0
# District          0.0
# Headquarters      0.0
# Population        0.0
# Area (sq km)      0.0
# Density           0.0
# Code              0.0
# Alternate Name    0.0
# dtype: float64

# %%
# 1.3 Question Number 3
(State_txn.isnull().mean()*100).idxmax()
(State_txnsplit.isnull().mean()*100).idxmax()
(State_devicedata.isnull().mean()*100).idxmax()
(District_txn.isnull().mean()*100).idxmax()
(District_demo.isnull().mean()*100).idxmax()
# Out:
# 'State'

# %%
#1.4 Question-1 Total Number of state and total number of districts.

District_demo["State"].nunique()
District_demo["District"].nunique()
# Out:
# 736

# %%
#1.4 Question-2

# 1st Method
District_demo.groupby("State").size().idxmax()

# ## 2nd method
# District_demo["State"].value_counts().idxmax()
# Out:
# 'Uttar Pradesh'

# %%
#2.1 Question-1 Total Number of transation and the total amount spent in terms of the tebular format.

State_txn.groupby(["State", "Year"]).agg(Total_transaction= ("Transactions", "sum"), Total_amount= ("Amount (INR)", "sum")).reset_index()
# Out:
#                          State  Year  Total_transaction  Total_amount
# 0    Andaman & Nicobar Islands  2018              58021  1.890761e+08
# 1    Andaman & Nicobar Islands  2019             133104  4.734648e+08
# 2    Andaman & Nicobar Islands  2020             446274  1.296423e+09
# 3    Andaman & Nicobar Islands  2021             586166  1.682854e+09
# 4               Andhra Pradesh  2018           77779112  1.220720e+11
# ..                         ...   ...                ...           ...
# 139                Uttarakhand  2021           44608834  7.727901e+10
# 140                West Bengal  2018          120011635  1.115887e+11
# 141                West Bengal  2019          257900590  2.660145e+11
# 142                West Bengal  2020          304222327  5.527316e+11
# 143                West Bengal  2021          260151489  5.223720e+11
#
# [144 rows x 4 columns]

# %%
# 2.1 Question-2 Top 5 and bottom 5 state, on the basis of transaction.

# Top 5 State.
State_txn.groupby(["State"])["Transactions"].sum().nlargest(5)

#Bottom 5 State.
State_txn.groupby(["State"])["Transactions"].sum().nsmallest(5)
# Out:
# State
# Lakshadweep                    71610
# Andaman & Nicobar Islands    1223565
# Ladakh                       1880109
# Mizoram                      2162776
# Meghalaya                    5648913
# Name: Transactions, dtype: int64

# %%
# 2.2 Most frequant transaction type.
All_transaction = State_txnsplit.groupby(["State","Quarter","Transaction Type"]).agg(total_transactions = ("Transactions", "sum")).reset_index()
index= All_transaction.groupby(["State","Quarter"])["total_transactions"].idxmax().tolist()

# Most frequant transaction type.
All_transaction.loc[index]
# Out:
#                          State  Quarter          Transaction Type  \
# 3    Andaman & Nicobar Islands        1     Peer-to-peer payments
# 9    Andaman & Nicobar Islands        2  Recharge & bill payments
# 14   Andaman & Nicobar Islands        3  Recharge & bill payments
# 18   Andaman & Nicobar Islands        4     Peer-to-peer payments
# 23              Andhra Pradesh        1     Peer-to-peer payments
# ..                         ...      ...                       ...
# 698                Uttarakhand        4     Peer-to-peer payments
# 703                West Bengal        1     Peer-to-peer payments
# 708                West Bengal        2     Peer-to-peer payments
# 713                West Bengal        3     Peer-to-peer payments
# 718                West Bengal        4     Peer-to-peer payments
#
#      total_transactions
# 3                138772
# 9                180447
# 14                84165
# 18               110018
# 23            255236515
# ..                  ...
# 698            11515030
# 703           114083760
# 708           118087640
# 713           100961691
# 718           130629804
#
# [144 rows x 4 columns]

# %%
# 2.3

Device_users_by_brand= State_devicedata.groupby(["State","Brand"])["Registered Users"].sum().reset_index()
Device_users_by_brand.loc[Device_users_by_brand.groupby("State")["Registered Users"].idxmax()]
# Out:
#                                     State    Brand  Registered Users
# 11              Andaman & Nicobar Islands   Xiaomi             97889
# 22                         Andhra Pradesh   Xiaomi          40061549
# 34                      Arunachal Pradesh   Xiaomi            437803
# 46                                  Assam   Xiaomi           6979357
# 60                                  Bihar   Xiaomi          33721314
# 73                             Chandigarh   Xiaomi            896628
# 85                           Chhattisgarh   Xiaomi           8763373
# 98   Dadra & Nagar Haveli and Daman & Diu   Xiaomi            638834
# 109                                 Delhi   Xiaomi          24114984
# 120                                   Goa   Xiaomi           1208672
# 131                               Gujarat   Xiaomi          28942157
# 143                               Haryana   Xiaomi          21102142
# 156                      Himachal Pradesh   Xiaomi           3978888
# 168                       Jammu & Kashmir   Xiaomi           3471820
# 182                             Jharkhand   Xiaomi          12824023
# 193                             Karnataka   Xiaomi          52595345
# 204                                Kerala   Xiaomi          12271469
# 216                                Ladakh   Xiaomi            167017
# 229                           Lakshadweep   Xiaomi              6979
# 242                        Madhya Pradesh   Xiaomi          32789227
# 253                           Maharashtra   Xiaomi          80281858
# 268                               Manipur   Xiaomi           1079740
# 281                             Meghalaya   Xiaomi            347937
# 293                               Mizoram   Xiaomi            193013
# 306                              Nagaland   Xiaomi            440693
# 318                                Odisha   Xiaomi          22935907
# 329                            Puducherry   Xiaomi            637639
# 343                                Punjab   Xiaomi          11064360
# 356                             Rajasthan   Xiaomi          33767499
# 368                                Sikkim  Samsung            406392
# 382                            Tamil Nadu   Xiaomi          31519236
# 393                             Telangana   Xiaomi          38954882
# 406                               Tripura   Xiaomi            913017
# 421                         Uttar Pradesh   Xiaomi          64303360
# 434                           Uttarakhand   Xiaomi           5519705
# 447                           West Bengal   Xiaomi          38265764

# %%
#2.4 Question-1
High_population_dis= District_demo.groupby(["State", "District"])[["Population"]].sum().reset_index()
State_dis= High_population_dis.loc[High_population_dis.groupby("State")["Population"].idxmax()].reset_index(drop = True)

# District with the highest population.
State_dis
# Out:
#                                    State                District  Population
# 0              Andaman & Nicobar Islands           South Andaman      238142
# 1                         Andhra Pradesh           East Godavari     5151549
# 2                      Arunachal Pradesh              Papum Pare      176385
# 3                                  Assam                  Nagaon     2826006
# 4                                  Bihar                   Patna     5772804
# 5                             Chandigarh              Chandigarh     1055450
# 6                           Chhattisgarh                  Raipur     2160876
# 7   Dadra & Nagar Haveli and Daman & Diu  Dadra and Nagar Haveli      343709
# 8                                  Delhi        North West Delhi     3656539
# 9                                    Goa               North Goa      817761
# 10                               Gujarat               Ahmedabad     7208200
# 11                               Haryana               Faridabad     1798954
# 12                      Himachal Pradesh                  Kangra     1507223
# 13                       Jammu & Kashmir                   Jammu     1526406
# 14                             Jharkhand                  Ranchi     2912022
# 15                             Karnataka         Bangalore Urban     9588910
# 16                                Kerala              Malappuram     4110956
# 17                                Ladakh                  Kargil      143388
# 18                           Lakshadweep             Lakshadweep       64473
# 19                        Madhya Pradesh                  Indore     3272335
# 20                           Maharashtra                    Pune     9426959
# 21                               Manipur             Imphal West      514683
# 22                             Meghalaya        East Khasi Hills      824059
# 23                               Mizoram                  Aizawl      404054
# 24                              Nagaland                Tuensang      414801
# 25                                Odisha                  Ganjam     3520151
# 26                            Puducherry              Puducherry      950289
# 27                                Punjab                Ludhiana     3487882
# 28                             Rajasthan                  Jaipur     6663971
# 29                                Sikkim             East Sikkim      281293
# 30                            Tamil Nadu                 Chennai     7139882
# 31                             Telangana               Hyderabad     3943323
# 32                               Tripura            West Tripura      917534
# 33                         Uttar Pradesh               Allahabad     5959798
# 34                           Uttarakhand                Haridwar     1927029
# 35                           West Bengal       North 24 Parganas    10082852

# %%
# Question 2.
# Display the column char for the district with the highest population.
plt.figure(figsize= [16, 9])

State_district= State_dis["State"].astype("str")+"-*"+State_dis["District"].astype("str")

plt.xticks(rotation=90)
plt.bar(State_district, State_dis["Population"])

# Labels
plt.xlabel("Districts")
plt.ylabel("Population")
plt.title("Population by District")
# Out:
# Text(0.5, 1.0, 'Population by District')

# %%
# 2.5 Question-1
# Calculate the average transaction value for each state.

avg_txn= (State_txn.groupby("State").agg(total_amount= ("Amount (INR)","sum"), total_transaction= ("Transactions", "sum"))).reset_index()
avg_txn["Avg_transactions"]= avg_txn["total_amount"]/avg_txn["total_transaction"]

avg_txn[["State", "Avg_transactions"]]
# Out:
#                                    State  Avg_transactions
# 0              Andaman & Nicobar Islands       2976.399178
# 1                         Andhra Pradesh       1789.828350
# 2                      Arunachal Pradesh       2766.333539
# 3                                  Assam       2277.175192
# 4                                  Bihar       2297.474906
# 5                             Chandigarh       2104.990740
# 6                           Chhattisgarh       1718.150602
# 7   Dadra & Nagar Haveli and Daman & Diu       1497.232192
# 8                                  Delhi       1631.940078
# 9                                    Goa       1808.372977
# 10                               Gujarat       1803.167412
# 11                               Haryana       1866.717628
# 12                      Himachal Pradesh       1846.955544
# 13                       Jammu & Kashmir       2430.351780
# 14                             Jharkhand       1782.135258
# 15                             Karnataka       1463.042846
# 16                                Kerala       1667.695461
# 17                                Ladakh       3514.146494
# 18                           Lakshadweep       2683.405735
# 19                        Madhya Pradesh       1740.599390
# 20                           Maharashtra       1514.288897
# 21                               Manipur       2905.757931
# 22                             Meghalaya       2220.183227
# 23                               Mizoram       2920.848685
# 24                              Nagaland       2794.140997
# 25                                Odisha       1648.411793
# 26                            Puducherry       1856.174886
# 27                                Punjab       2173.728990
# 28                             Rajasthan       1898.581540
# 29                                Sikkim       2183.167483
# 30                            Tamil Nadu       1850.884907
# 31                             Telangana       1948.618449
# 32                               Tripura       1744.903440
# 33                         Uttar Pradesh       1825.306791
# 34                           Uttarakhand       1734.291239
# 35                           West Bengal       1541.683482

# %%
## Key finding
# avg_txn.loc[avg_txn["Avg_transactions"]== avg_txn["Avg_transactions"].min()]

# %%
# 2.5 Question 2
avg_txn.nlargest(columns="Avg_transactions", n= 5)
avg_txn.nsmallest(columns="Avg_transactions", n= 5)
# Out:
#                                    State  total_amount  total_transaction  \
# 15                             Karnataka  4.361396e+12         2981044533
# 7   Dadra & Nagar Haveli and Daman & Diu  1.865878e+10           12462185
# 20                           Maharashtra  4.290995e+12         2833670154
# 35                           West Bengal  1.452707e+12          942286041
# 8                                  Delhi  1.649942e+12         1011031124
#
#     Avg_transactions
# 15       1463.042846
# 7        1497.232192
# 20       1514.288897
# 35       1541.683482
# 8        1631.940078

# %%
# 2.6 app opens over the years.
# Question 1

App_open_sum= District_txn.groupby(["State","Year", "Quarter"])[["App Opens"]].sum().reset_index()
App_open_sum
# Out:
#                          State  Year  Quarter  App Opens
# 0    Andaman & Nicobar Islands  2018        1          0
# 1    Andaman & Nicobar Islands  2018        2          0
# 2    Andaman & Nicobar Islands  2018        3          0
# 3    Andaman & Nicobar Islands  2018        4          0
# 4    Andaman & Nicobar Islands  2019        1          0
# ..                         ...   ...      ...        ...
# 499                West Bengal  2020        2  198589332
# 500                West Bengal  2020        3  246554831
# 501                West Bengal  2020        4  291721919
# 502                West Bengal  2021        1  316832674
# 503                West Bengal  2021        2  275341466
#
# [504 rows x 4 columns]

# %%
#2.6 Quetion 2
plt.figure(figsize= [16, 9])
plt.xticks(rotation=90)
App_open_sum["Year+Quarter"]= App_open_sum["Year"].astype(str)+ "-Q" + App_open_sum["Quarter"].astype(str)

y= App_open_sum.loc[App_open_sum["State"]== "Delhi", "App Opens"]
x= App_open_sum.loc[App_open_sum["State"]== "Delhi", "Year+Quarter"]

plt.plot(x,y)

plt.xlabel("Year & Quarter")
plt.ylabel("App Opens")
plt.title("App Open Trend- Delhi")
# Out:
# Text(0.5, 1.0, 'App Open Trend- Delhi')

# %%
# 2.7 Quetion 1
recent_year= State_txnsplit["Year"].max()
recent_quarter= State_txnsplit.loc[State_txnsplit["Year"]== State_txnsplit["Year"].max(), "Quarter"].max()
Subset= State_txnsplit.loc[(State_txnsplit["Year"]==recent_year) & (State_txnsplit["Quarter"]==recent_quarter)]

Subset.groupby(["State", "Transaction Type"])["Transactions"].sum()

## Now plot it
plt.figure(figsize= [16, 9])
plt.xticks(rotation=90)

sns.barplot(data= Subset, x= "State", y= "Transactions", hue= "Transaction Type")

plt.title("State wise Transaction- Distribution")
# Out:
# Text(0.5, 1.0, 'State wise Transaction- Distribution')

# %%
# 2.8 Question 1.
Unique_dis= District_demo[["District", "Code"]].drop_duplicates()

# Question 2.
Unique_dis.to_csv("Unique_district_mapping.csv", index=False)

# %%
# 3.1, Question 1

Dis_TAU= District_txn.groupby("State")[["Transactions", "Amount (INR)", "Registered Users"]].sum().reset_index()

# Question 2
State_TAU= State_txn.groupby("State")[["Transactions", "Amount (INR)", "Registered Users"]].sum().reset_index()

Comparison= ~(Dis_TAU== State_TAU).all(axis=1)

# Question 3
Dis_TAU.loc[Comparison].reset_index(drop= True)
# Out:
#                                    State  Transactions  Amount (INR)  \
# 0              Andaman & Nicobar Islands       1223565  3.641818e+09
# 1                         Andhra Pradesh    1781091169  3.860292e+12
# 2                      Arunachal Pradesh       8043799  2.225183e+10
# 3                                  Assam     123577981  2.814087e+11
# 4                                  Bihar     713643889  1.639579e+12
# 5                             Chandigarh      25516542  5.371208e+10
# 6                           Chhattisgarh     241908549  4.156353e+11
# 7   Dadra & Nagar Haveli and Daman & Diu      12462185  1.865878e+10
# 8                                  Delhi    1011031124  1.649942e+12
# 9                                    Goa      24481604  4.427187e+10
# 10                               Gujarat     612992823  1.105329e+12
# 11                               Haryana     567751410  1.059832e+12
# 12                      Himachal Pradesh      52987445  9.786546e+10
# 13                       Jammu & Kashmir      45053328  1.094954e+11
# 14                             Jharkhand     275270987  4.905701e+11
# 15                             Karnataka    2981044533  4.361396e+12
# 16                                Kerala     223637876  3.729599e+11
# 17                                Ladakh       1880109  6.606978e+09
# 18                           Lakshadweep         71610  1.921587e+08
# 19                        Madhya Pradesh    1100253728  1.915101e+12
# 20                           Maharashtra    2833670154  4.290995e+12
# 21                             Meghalaya       5648913  1.254162e+10
# 22                               Mizoram       2162776  6.317141e+09
# 23                              Nagaland       5864977  1.638757e+10
# 24                                Odisha     740479146  1.220615e+12
# 25                            Puducherry      17292386  3.209769e+10
# 26                                Punjab     181336904  3.941773e+11
# 27                             Rajasthan    1382918930  2.625584e+12
# 28                                Sikkim       6483948  1.415554e+10
# 29                            Tamil Nadu     800399873  1.481448e+12
# 30                             Telangana    2347430243  4.574246e+12
# 31                               Tripura      12018152  2.097051e+10
# 32                         Uttar Pradesh    1314714390  2.399757e+12
# 33                           Uttarakhand     124011162  2.150715e+11
# 34                           West Bengal     942286041  1.452707e+12
#
#     Registered Users
# 0             408396
# 1          158007957
# 2            1862214
# 3           26860751
# 4          115284760
# 5            3801466
# 6           37448388
# 7            2701112
# 8           95374654
# 9            4755320
# 10         126380032
# 11          85564119
# 12          13373980
# 13           9756438
# 14          44768682
# 15         203098564
# 16          51267042
# 17            579825
# 18             34223
# 19         125339823
# 20         315783658
# 21           1436472
# 22            605612
# 23           1440387
# 24          80404103
# 25           2785162
# 26          45811761
# 27         149770064
# 28           1279199
# 29         132437426
# 30         149224214
# 31           3661575
# 32         246200404
# 33          23792747
# 34         144242183

# %%
#4.1 Quetions 1

# Merging the dataset.
demo = District_demo.groupby("State")["Population"].sum()
combined_statetxn_dis= State_txn.merge(demo, on=["State"], how="left")

## Population Ratio.
Ratio= combined_statetxn_dis.groupby("State")["Registered Users"].sum()/combined_statetxn_dis.groupby("State")["Population"].sum()
Ratio
# Out:
# State
# Andaman & Nicobar Islands               0.076649
# Andhra Pradesh                          0.228565
# Arunachal Pradesh                       0.082822
# Assam                                   0.055675
# Bihar                                   0.079318
# Chandigarh                              0.257268
# Chhattisgarh                            0.103405
# Dadra & Nagar Haveli and Daman & Diu    0.328707
# Delhi                                   0.405796
# Goa                                     0.233011
# Gujarat                                 0.136919
# Haryana                                 0.236381
# Himachal Pradesh                        0.139325
# Jammu & Kashmir                         0.056851
# Jharkhand                               0.097001
# Karnataka                               0.237953
# Kerala                                  0.109679
# Ladakh                                  0.149584
# Lakshadweep                             0.037915
# Madhya Pradesh                          0.121076
# Maharashtra                             0.200713
# Manipur                                 0.051939
# Meghalaya                               0.030493
# Mizoram                                 0.039649
# Nagaland                                0.044059
# Odisha                                  0.136913
# Puducherry                              0.159413
# Punjab                                  0.107249
# Rajasthan                               0.155899
# Sikkim                                  0.150359
# Tamil Nadu                              0.124441
# Telangana                               0.293095
# Tripura                                 0.071245
# Uttar Pradesh                           0.085423
# Uttarakhand                             0.167987
# West Bengal                             0.110989
# dtype: float64

# %%
#4.1 Quetions 2
plt.xticks(rotation= 90)
plt.ylabel("Ratio")
plt.title("Registered:Population Ratio")
plt.figure(figsize= [16,9])

## Plot
Ratio.plot(kind= "bar")
# Out:
# <Axes: xlabel='State'>

# %%
# 4.2 Question 1
combined_distxn_disdemo= District_txn.merge(District_demo[["State", "District", "Code", "Density"]], on=["State", "District", "Code"], how="left")

#Data
combined_distxn_disdemo
# Out:
#                            State  Year  Quarter                    District  \
# 0      Andaman & Nicobar Islands  2018        1                    Nicobars
# 1      Andaman & Nicobar Islands  2018        1    North And Middle Andaman
# 2      Andaman & Nicobar Islands  2018        1               South Andaman
# 3      Andaman & Nicobar Islands  2018        2                    Nicobars
# 4      Andaman & Nicobar Islands  2018        2    North And Middle Andaman
# ...                          ...   ...      ...                         ...
# 10243                West Bengal  2021        2             Purba Bardhaman
# 10244                West Bengal  2021        2             Purba Medinipur
# 10245                West Bengal  2021        2                     Purulia
# 10246                West Bengal  2021        2  South Twenty Four Parganas
# 10247                West Bengal  2021        2              Uttar Dinajpur
#
#        Code  Transactions  Amount (INR)    ATV (INR)  Registered Users  \
# 0      AN01           528  1.139849e+06  2158.804548               262
# 1      AN02           442  9.316631e+05  2107.835016               632
# 2      AN03          5688  1.256025e+07  2208.201361              5846
# 3      AN01          1120  3.072437e+06  2743.247239               351
# 4      AN02           825  1.317863e+06  1597.409798               911
# ...     ...           ...           ...          ...               ...
# 10243  WB19       3920729  7.572502e+09  1931.401639            787970
# 10244  WB20       6418522  1.515507e+10  2361.146027            946277
# 10245  WB21       1895981  2.790996e+09  1472.059252            435131
# 10246  WB22       6661813  1.339853e+10  2011.243709           1286588
# 10247  WB23       2253385  5.564221e+09  2469.272118            392388
#
#        App Opens  Density
# 0              0      NaN
# 1              0      NaN
# 2              0     89.0
# 3              0      NaN
# 4              0      NaN
# ...          ...      ...
# 10243   12128849    890.0
# 10244   15491958   1076.0
# 10245    8843358    468.0
# 10246   19344293      NaN
# 10247    8184990    956.0
#
# [10248 rows x 11 columns]

# %%
# 4.2 Question 2.

plt.figure(figsize= [16,9])
plt.title("Transaction&Density")
a= combined_distxn_disdemo.groupby("State")["Transactions"].sum()
b= combined_distxn_disdemo.groupby("State")["Density"].sum()

#Plot
sns.scatterplot(x=b,y=a)
# Out:
# <Axes: title={'center': 'Transaction&Density'}, xlabel='Density', ylabel='Transactions'>

# %%
# 4.3 Question 1 dataset is already present in State_txn
# question4 = State_txnsplit.merge(State_txn[["State", "Quarter", "Year", "Registered Users", "App Opens"]], on=["State", "Quarter", "Year"], how="left")

# With the help of user defined function
def avg_transaction(x):
    return x["Amount (INR)"].sum()/ x["Registered Users"].sum()

# Apply the function
Avg_amount_per_user = State_txn.groupby("State").apply(avg_transaction).reset_index().rename(columns={0: "Avg_amount"})

# %%
# 4.3 Question 2
# Top 5
Avg_amount_per_user.nlargest(columns= "Avg_amount", n=5)

# Bottom 5
Avg_amount_per_user.nsmallest(columns= "Avg_amount", n=5)
# Out:
#                                    State   Avg_amount
# 18                           Lakshadweep  5614.898889
# 32                               Tripura  5727.184275
# 7   Dadra & Nagar Haveli and Daman & Diu  6907.815954
# 16                                Kerala  7274.846690
# 12                      Himachal Pradesh  7317.601442

# %%
# 4.4 Question 1
## Subset
Subset1= State_devicedata.groupby(["State", "Brand"])["Registered Users"].sum().reset_index()
Subset2= State_txn.groupby("State")["Registered Users"].sum()

#Merge
Ratio_of_registered_users= Subset1.merge(Subset2, on= "State", how= "left")

# %%
#4.4 Question 2
#Ratio
Ratio_of_registered_users["Ratio by brand"] = Ratio_of_registered_users["Registered Users_x"]/ Ratio_of_registered_users["Registered Users_y"]

#Output
Ratio_of_registered_users[["State", "Ratio by brand"]]
# Out:
#                          State  Ratio by brand
# 0    Andaman & Nicobar Islands        0.022855
# 1    Andaman & Nicobar Islands        0.028152
# 2    Andaman & Nicobar Islands        0.013129
# 3    Andaman & Nicobar Islands        0.023240
# 4    Andaman & Nicobar Islands        0.037701
# ..                         ...             ...
# 443                West Bengal        0.121508
# 444                West Bengal        0.064628
# 445                West Bengal        0.211563
# 446                West Bengal        0.130025
# 447                West Bengal        0.265288
#
# [448 rows x 2 columns]

# %%
## 4.4 Question 3

plt.figure(figsize= [16, 9])
plt.xticks(rotation=90)

sns.barplot(data= Ratio_of_registered_users, x= "State", y= "Ratio by brand", hue= "Brand")

plt.title("Device Brand Usage")
# Out:
# Text(0.5, 1.0, 'Device Brand Usage')

# %%
#5.1 Lineplot
#Subset data
# selected_state = str(input("Please enter the state of your choice")).capitalize()

selected_state = "Delhi"
state_data = State_txn[State_txn["State"] == selected_state]

state_data["Year_Quarter"] = state_data["Year"].astype(str) + "-Q" + state_data["Quarter"].astype(str)

summary = state_data.groupby("Year_Quarter").agg(total_transactions=("Transactions", "sum"),total_amount=("Amount (INR)", "sum")).reset_index()

#Plot
plt.figure(figsize= [16, 9])
plt.xticks(rotation=90)

sns.lineplot(data=summary, x= summary["Year_Quarter"], y= summary["total_transactions"])

plt.xlabel("Year & Quarter")
plt.ylabel("Transactions")
plt.title("Transaction Trend- Delhi")
# Out:
# Text(0.5, 1.0, 'Transaction Trend- Delhi')

# %%
## Plot Amount Trend
plt.figure(figsize= [16, 9])
plt.xticks(rotation=90)

sns.lineplot(data=summary, x= summary["Year_Quarter"], y= summary["total_amount"])

plt.xlabel("Year & Quarter")
plt.ylabel("Amount")
plt.title("Amount Trend- Delhi")
# Out:
# Text(0.5, 1.0, 'Amount Trend- Delhi')

# %%
#5.2
Subset= State_txnsplit.loc[(State_txnsplit["Quarter"]==4) & (State_txnsplit["State"] == "West Bengal")]

## Plot
value= Subset.groupby("Transaction Type")["Transactions"].sum()
plt.figure(figsize= [10,8])
plt.title("Transactions: Delhi-Quarter4")

plt.pie(x=value, labels=value.index, autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x20e5be35700>,
#   <matplotlib.patches.Wedge at 0x20e5c4ea600>,
#   <matplotlib.patches.Wedge at 0x20e5befbad0>,
#   <matplotlib.patches.Wedge at 0x20e5bf380e0>,
#   <matplotlib.patches.Wedge at 0x20e5bf38680>],
#  [Text(1.099755904643965, 0.023172185929127214, 'Financial Services'),
#   Text(0.8023288737140407, 0.7525080586975527, 'Merchant payments'),
#   Text(0.09496672606317896, 1.0958929331558085, 'Others'),
#   Text(-1.092239490992051, -0.13043348618137068, 'Peer-to-peer payments'),
#   Text(0.886751719025216, -0.6509004446194707, 'Recharge & bill payments')],
#  [Text(0.5998668570785264, 0.012639374143160296, '0.67%'),
#   Text(0.4376339311167494, 0.41045894110775594, '22.64%'),
#   Text(0.05180003239809761, 0.59775978172135, '0.63%'),
#   Text(-0.5957669950865732, -0.07114553791711127, '55.91%'),
#   Text(0.48368275583193593, -0.3550366061560749, '20.16%')])

# %%
## 6.1
#Subset data
selected_state = "Uttarakhand"
state_data = State_txn[State_txn["State"] == selected_state]

state_data["Year_Quarter"] = state_data["Year"].astype(str) + "-Q" + state_data["Quarter"].astype(str)

summary = state_data.groupby("Year_Quarter").agg(total_transactions=("Transactions", "sum"), total_amount= ("Amount (INR)", "sum")).reset_index()


#linepolt
plt.xticks(rotation=45)

sns.lineplot(data=summary, x= summary["Year_Quarter"], y= summary["total_transactions"])

plt.xlabel("Year & Quarter")
plt.ylabel("Amount")
plt.title("Transaction Trend- Uttarakhand")
# Out:
# Text(0.5, 1.0, 'Transaction Trend- Uttarakhand')

# %%
## 6.2

Density= District_demo.groupby("State").agg(total_density= ("Density", "sum")).reset_index()
Transactions= District_txn.groupby("State").agg(total_transaction= ("Transactions", "sum")).reset_index()

## Merge
Merged_dataset= Density.merge(Transactions, on= ["State"], how= "left")

##Correlation
Merged_dataset["total_density"].corr(Merged_dataset["total_transaction"])
# Out:
# 0.39684437273582057

# %%
# Key findings 6.3

# %%
# Transaction Trend, demographic corrl, device usage

# %%
# Checking the corrl between total transaction and total amount.

summary["total_transactions"].corr(summary["total_amount"])
# Out:
# 0.9975354359324407

# %% [markdown]
# 1. Xiaomi has the most registered users, making it the leading brand.
#  Suggestions: We can run the promotions with the other brands to Device brand to target more number of users.
#
# 2. State of Karnataka contributed to the most number of transactions 29.81-billion with ATV(1463.04) per transactions from 2018,
#       following the state of Maharashtra 28.33-billion transactions with ATV(1514.28).
#  Suggestions: We need to focus on other states as the number of transaction is low like:Lakshadweep only 71610 with ATV(2683.40) from 2018,
#     and Andaman & Nicobar Islands 1223565 with ATV(2976.39).
#
# 3.There is a clear correlation between the number of transactions and the amount.
#       Increasing the number of transactions results in an increase in the total transaction amount.
#  Suggestions: We can target the small businesses to target higher number of population.
#
# 4. There is a moderate positive relationship between density and transaction volume.
#       It can be inferred that when the density is high, the number of transactions also rises.
#  Suggestions: Need to focus on more denser areas of the district to increase the transaction volume.
#
# 6.1
# 4. The number of online transactions has been consistently rising since the 2018.
#       However, a significant decrease in transactions was observed in Q2 2020 across all states.(possibly Due to the covid outbreak)
#        Following this period, the trend sharply reversed, showing a significant upward trajectory.
